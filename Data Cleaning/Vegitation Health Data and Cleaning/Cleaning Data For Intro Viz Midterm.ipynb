# %%
import numpy as np
import matplotlib.pyplot as plt
#import h5py
# %matplotlib inline

# %%
#filename = "Vegetation Health Data.hdf"
fname = "VHI.txt"
file = fname

# %%
#doesn't work
#key ="VHI" #dunno if this should be the key or if it even needs one
#import pandas as pd
#pd.read_hdf(filename, key)

# %%
vhi = np.loadtxt(fname, dtype=int, delimiter="\t")
#vhi = np.fromfile(fname, dtype=int)
#vhi.reshape(903,2500)
print(vhi.shape)
print(vhi[1,1])
# Out:
# (904, 2500)
# -999

# %%
plt.imshow(vhi, cmap='summer', interpolation='nearest')
plt.show()

# %%
supbsetVhi =vhi[220:290,380:445]
plt.imshow(supbsetVhi, cmap='summer', interpolation='nearest')
plt.show()
